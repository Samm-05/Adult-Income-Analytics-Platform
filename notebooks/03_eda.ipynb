# %% [markdown]
# Library Import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load Data

# %%
df = pd.read_csv(
    "../data/processed/cleaned_adult.csv"
)

# %% [markdown]
# Income Distribution

# %%
sns.countplot(
    data=df,
    x="income"
)

plt.show()

# %% [markdown]
# Age Distribution

# %%
plt.figure(figsize=(10,5))

sns.histplot(
    df["age"],
    bins=30
)

plt.show()

# %% [markdown]
# Education Distribution

# %%
plt.figure(figsize=(12,5))

sns.countplot(
    data=df,
    x="education"
)

plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# Gender vs Income

# %%
sns.countplot(
    data=df,
    x="sex",
    hue="income"
)

plt.show()

# %% [markdown]
# Occupation Analysis

# %%
plt.figure(figsize=(15,6))

sns.countplot(
    data=df,
    y="occupation",
    order=df["occupation"]
    .value_counts()
    .index
)

plt.show()

# %% [markdown]
# Correlation Matrix

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

num_cols = df.select_dtypes(
    include=np.number
)

plt.figure(figsize=(10,8))

sns.heatmap(
    num_cols.corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Matrix")
plt.show()

# %%
plt.savefig(
    "../reports/screenshots/correlation.png"
)

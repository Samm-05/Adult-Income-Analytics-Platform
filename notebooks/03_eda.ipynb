# %% [markdown]
# Library Import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load Data

# %%
df = pd.read_csv(
    "../data/processed/cleaned_adult.csv"
)

# %% [markdown]
# Income Distribution

# %%
sns.countplot(
    data=df,
    x="income"
)

plt.show()
